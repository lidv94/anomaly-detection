# %% [markdown]
# # REVISE
# ![image.png](attachment:6d83b134-eddf-4a26-978d-d42c4b9d2add.png)

# %% [markdown]
# # Read Library

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install tqdm

# %%
# !pip install torchview

# %%
# !pip install torchinfo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torchinfo import summary
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import math
from scipy import stats
import warnings
import re
import datetime
from package.utils import profile_data ,DotDict, timer, get_config, load_data, merge_data

# %%
from package.model_deep_ae import (set_seed,
                                generate_mock_data,
                                expand_rule_columns,
                                subset_by_timeunit,
                                split_train_test,
                                prepare_train_val_test_data,
                                Autoencoder,
                                train_autoencoder,
                                save_checkpoint,
                                load_checkpoint     ,
                                train_autoencoder_checkpoint     ,
                                load_pickled_autoencoder     ,
                                plot_learning_curve,
                                get_reconstruction_error,
                                plot_threshold_vs_metric_percentile,
                                flag_anomalies,
                                detect_anomalies,
                                tune_autoencoder_grid,
                                extract_embeddings,
                                plot_latent_space,
                                create_pack_results,
                                append_experiment_results
                                )

from package.model_deep_ae import (evaluate_fraud_predictions,
                                evaluate_thresholds,
                                )

# %% [markdown]
# # Read Data

# %%
mock1 = generate_mock_data(n_sales=10000, n_rules=10, fraud_ratio=0.05, seed=42)
mock1
# Out:
# function: generate_mock_data is starting...
# function: generate_mock_data successfully executed at 1.400428056716919s
#        sales_id timeunit  flag_fraud    rule_1    rule_2    rule_3    rule_4  \
# 0             0       l3           0 -1.487862 -1.125186  0.388819 -1.173873
# 1             1       l3           1  4.182238  3.601215  2.665470  2.039528
# 2             2       l3           0  0.608267  1.345935 -0.174648  1.360168
# 3             3       l3           0 -1.972089  0.288028 -1.443926  0.444854
# 4             4       l3           0 -1.415524  0.977872 -0.270371 -1.389780
# ...         ...      ...         ...       ...       ...       ...       ...
# 59995      9995      l36           0  0.647493 -0.163831 -1.743780  1.184970
# 59996      9996      l36           0 -0.716390  1.700367 -0.933375  0.191027
# 59997      9997      l36           0  1.066770 -1.592284 -1.706892  1.178747
# 59998      9998      l36           0  1.622065 -0.303766  1.377932 -0.777375
# 59999      9999      l36           0 -0.627238  0.802268  0.370617  0.899228
#
#          rule_5    rule_6    rule_7    rule_8    rule_9   rule_10
# 0      1.112634 -0.071120  0.085595 -0.278373  0.772848  0.783160
# 1      3.012423  6.067259  3.677239  3.582941  2.306755  1.086816
# 2     -0.189693  0.849585 -2.218570  2.418778  1.495458 -0.284626
# 3      0.411566 -0.941403  1.120967  0.805575  0.975823  0.008858
# 4      1.352039  2.099408 -0.041248  2.159121  0.091315 -0.380456
# ...         ...       ...       ...       ...       ...       ...
# 59995 -0.193500 -1.273190  0.773532 -1.803990  2.209333 -0.800634
# 59996 -1.348096  2.584121 -0.054343 -1.355835  1.124099  0.609250
# 59997  0.985029  0.364593 -2.039914 -0.325981  0.478952  0.808948
# 59998 -0.179569  0.607243 -1.106324 -0.591367  0.501293  0.450664
# 59999 -1.062791 -0.834835  0.212760 -0.731499 -0.355249 -0.062371
#
# [60000 rows x 13 columns]

# %% [markdown]
# # Autoencoder

# %% [markdown]
# - Autoencoder คือ neural network ที่เรียนรู้จะ compress ข้อมูล (encode) แล้ว reconstruct ข้อมูลเดิม (decode) ให้ใกล้เคียงที่สุด
# - Encoder → บีบข้อมูลจาก input ขนาดใหญ่เป็น latent space ขนาดเล็ก
# - Latent space → ข้อมูลสรุปที่มีมิติเล็กลง (เรียกว่า embedding)
# - Decoder → แปลง latent space กลับเป็น input เดิม
# - OBJ: เรียนรู้โครงสร้างหรือ pattern ของข้อมูลปกติ

# %% [markdown]
# https://fraud-detection-handbook.github.io/fraud-detection-handbook/Chapter_7_DeepLearning/Autoencoders.html

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S1877050920306840?via%3Dihub

# %% [markdown]
# **Application to detect fraud**
# - Train autoencoder กับข้อมูลปกติ **[TUNE#1 Architecture]** and **[TUNE#2 Select Features]**
# - Predict: ให้ model reconstruct ข้อมูล test
# - คำนวณ reconstruction error using MSE โดย ถ้า error สูง → anomaly / fraud <br>
#     Normal data → model reconstruct ได้ดี → error ต่ำ <br>
#     Anomaly / novel data → model reconstruct ไม่ดี → error สูง <br>
#     จึงต้องมีการ **[TUNE#3 Threshold]**

# %% [markdown]
# ![image.png](attachment:3ae5a0d7-c849-4c10-ae33-11547b04836c.png)

# %% [markdown]
# ![image.png](attachment:77c64b8b-dff3-40d9-8aeb-11cb261c004d.png)
# https://www.softnix.co.th/2020/03/24/anomaly-detection-part-5-autoencoder/

# %% [markdown]
# ## Novelty Detection

# %% [markdown]
# ### Prep data

# %%
df_transformed = expand_rule_columns(mock1)
df_transformed
# Out:
# function: expand_rule_columns is starting...
# function: expand_rule_columns successfully executed at 0.4655025005340576s
#       sales_id  flag_fraud  rule_10_l12  rule_10_l24  rule_10_l3  rule_10_l36  \
# 0            0           0    -0.943490     0.000232    0.783160     0.668797
# 1            1           1     4.692913     4.551202    1.086816     3.403392
# 2            2           0    -0.090432     0.162957   -0.284626     1.460788
# 3            3           0    -0.474335    -0.921535    0.008858     0.198231
# 4            4           0     0.216357     0.160711   -0.380456    -0.865218
# ...        ...         ...          ...          ...         ...          ...
# 9995      9995           0     0.375382    -1.835668   -0.044578    -0.800634
# 9996      9996           0     0.345934    -1.321427   -2.077919     0.609250
# 9997      9997           0    -0.185466    -0.474796   -0.171683     0.808948
# 9998      9998           0    -0.992855     1.335352   -0.272822     0.450664
# 9999      9999           0    -1.782398     0.745420   -0.407116    -0.062371
#
#       rule_10_l6  rule_10_l9  rule_1_l12  rule_1_l24  ...  rule_8_l3  \
# 0       0.960825    0.888457   -0.389376    0.583561  ...  -0.278373
# 1       5.183808    1.615426    2.214356   -0.011207  ...   3.582941
# 2       0.862283    0.239878   -0.033178    0.214724  ...   2.418778
# 3       0.106144   -0.716708   -0.282492   -0.336470  ...   0.805575
# 4       0.443058    0.023325   -1.395400   -0.888219  ...   2.159121
# ...          ...         ...         ...         ...  ...        ...
# 0      -0.529068   0.419565   1.544185   -0.090537    2.602364   1.170655
# 1       0.224458   0.137280  -1.470905   -0.195771   -0.285033  -0.662554
# 2       0.172990  -0.734691  -0.170966   -0.031268   -0.474909  -0.477659
# 3      -1.630415  -1.231771  -0.090434   -0.445093   -0.174359  -0.614415
# 4       0.902149   1.032385  -0.601680    1.240849    1.074869   0.397844
# ...          ...        ...        ...         ...         ...        ...
# 1995    0.777990   0.094303   1.481645   -1.086707    0.063329  -0.257685
# 1996    0.700967  -2.289872  -0.574688   -1.977706   -0.002771   0.100661
# 1997    1.237131   1.381180   4.521633    0.911276    0.904070   2.291597
# 1998   -0.251481  -0.740706   1.015160    0.602499   -0.085554   1.258852
# 1999   -0.604906  -0.003083   1.758182    2.041881    0.764263  -0.021355
#
#       rule_9_l36  rule_9_l6  rule_9_l9
# 0      -1.028437  -0.395279  -0.738562
# 1      -0.034943  -0.482582   0.729810
# 2       1.127468   0.422860  -1.784257
# 3      -0.686898   1.044483   0.209088
# 4      -0.899164   0.898765   2.028315
# ...          ...        ...        ...
# 1995   -1.147627  -0.517380   0.017794
# 1996    1.146910   1.472190  -0.980250
# 1997    4.495184   4.679105   6.189663
# 1998    0.190123  -1.114771  -1.117456
# 1999    3.091110  -1.290316  -0.509218
#
# [2000 rows x 62 columns]

# %%
test_df['flag_fraud'].value_counts()
# Out:
# flag_fraud
# 0    1905
# 1      95
# Name: count, dtype: int64

# %%
test_df['flag_fraud'].value_counts(normalize=True)
# Out:
# flag_fraud
# 0    0.9525
# 1    0.0475
# Name: proportion, dtype: float64

# %%
# อย่าลืม scale นะจ้า
X_scaled_train, X_scaled_val, X_scaled_test, y_test = prepare_train_val_test_data(train_all_df, test_df,scale=True)
# Out:
# function: prepare_train_val_test_data is starting...
# function: prepare_train_val_test_data successfully executed at 0.018865108489990234s

# %%
X_scaled_train.shape # Train on non-fraud only
# Out:
# (6096, 60)

# %%
X_scaled_val.shape # val non-fraud only (sep from train)
# Out:
# (1525, 60)

# %%
X_scaled_test.shape # Test on all agent, even if it contains fraud, because you’re looking at the reconstruction error to flag anomalies
# Out:
# (2000, 60)

# %%
y_test.shape
# Out:
# (2000,)

# %%
true_fraud_list = test_df.loc[test_df['flag_fraud']==1,'sales_id'].to_list()
len(true_fraud_list)
# Out:
# 95

# %%
true_fraud_list
# Out:
# [8479,
#  3067,
#  9337,
#  8144,
#  2736,
#  932,
#  1425,
#  1348,
#  9841,
#  6959,
#  9164,
#  3649,
#  2906,
#  675,
#  4203,
#  6227,
#  3803,
#  2636,
#  2109,
#  7543,
#  5365,
#  2733,
#  4743,
#  5443,
#  8909,
#  9762,
#  5944,
#  6839,
#  6559,
#  1638,
#  9978,
#  2963,
#  5975,
#  5334,
#  5898,
#  2836,
#  4462,
#  3443,
#  6378,
#  6292,
#  3714,
#  9972,
#  5402,
#  2200,
#  1954,
#  5711,
#  8086,
#  3059,
#  4699,
#  5459,
#  2503,
#  2803,
#  1171,
#  8427,
#  1996,
#  1800,
#  3055,
#  1466,
#  518,
#  4036,
#  3846,
#  810,
#  5344,
#  7633,
#  2122,
#  464,
#  2460,
#  8929,
#  261,
#  6326,
#  8132,
#  411,
#  3696,
#  475,
#  4840,
#  1011,
#  8516,
#  3402,
#  4966,
#  7295,
#  9768,
#  412,
#  6117,
#  2798,
#  9777,
#  1715,
#  6051,
#  7225,
#  5286,
#  8616,
#  8458,
#  9129,
#  8160,
#  3506,
#  1440]

# %% [markdown]
# ### defining the architecture of the autoencoder
# - Building the layers (nn.Linear, nn.ReLU, etc.)
# - Structuring the encoder and decoder using nn.Sequential
# - Defining the forward() function for how data flows through the network
#   <br><br>
# **But this does not train anything yet.**

# %% [markdown]
# ![image.png](attachment:62f69d8d-82d7-494b-85f7-f1dc6cfb6074.png)

# %%
# design arch
in_x = X_scaled_train.shape[1] # จำนวน features -> input_dim
h1 = X_scaled_train.shape[1]//2 #  -> number of neuron in hidden layer 1
h2 = X_scaled_train.shape[1]//4 # -> hidden 2
h3 = X_scaled_train.shape[1]//8 # -> hidden 3

print(f'input layer dim = {in_x}')
print(f'hidden layer dim #1 = {h1}')
print(f'hidden layer dim #2 = {h2}')
print(f'hidden layer dim #3 = {h3}')
# Out:
# input layer dim = 60
# hidden layer dim #1 = 30
# hidden layer dim #2 = 15
# hidden layer dim #3 = 7

# %%
from torchinfo import summary
set_seed(42)

model_ae = Autoencoder(input_dim=in_x, 
                         encoding_dim=3, 
                         hidden_layers=[h1, 
                                        h2,
                                        h3,
                                       ],
                         verbose=False
                        )

# This is only used for testing the model architecture, not training or evaluating on real data.
dummy_input = torch.randn(5, X_scaled_train.shape[1]) 
summary(model_ae, input_data=dummy_input, verbose=0)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Autoencoder                              [5, 60]                   --
# ├─Sequential: 1-1                        --                        --
# │    └─Linear: 2-1                       [5, 30]                   1,830
# │    └─ReLU: 2-2                         [5, 30]                   --
# │    └─Linear: 2-3                       [5, 15]                   465
# │    └─ReLU: 2-4                         [5, 15]                   --
# │    └─Linear: 2-5                       [5, 7]                    112
# │    └─ReLU: 2-6                         [5, 7]                    --
# │    └─Linear: 2-7                       [5, 3]                    24
# ├─Sequential: 1-2                        --                        --
# │    └─Linear: 2-8                       [5, 7]                    28
# │    └─ReLU: 2-9                         [5, 7]                    --
# │    └─Linear: 2-10                      [5, 15]                   120
# │    └─ReLU: 2-11                        [5, 15]                   --
# │    └─Linear: 2-12                      [5, 30]                   480
# │    └─ReLU: 2-13                        [5, 30]                   --
# │    └─Linear: 2-14                      [5, 60]                   1,860
# ==========================================================================================
# Total params: 4,919
# Trainable params: 4,919
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.03
# ==========================================================================================

# %% [markdown]
# #### train model to learn normal pattern
# It trains an Autoencoder model to reconstruct its input, using mean squared error (MSE) as the loss.
# This lets the model learn the “normal pattern” of your data which you'll later use to detect anomalies.

# %% [markdown]
# #### loss  function and optimizer

# %% [markdown]
# https://docs.pytorch.org/docs/stable/nn.html#loss-functions

# %% [markdown]
# default : MSE

# %% [markdown]
# | Loss Function                                   | When to Use / Pros                                                                                      |
# | ----------------------------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **Mean Absolute Error (MAE)** (`nn.L1Loss()`)   | Less sensitive to outliers than MSE; good if you want robustness to large errors.                       |
# | **Binary Cross-Entropy (BCE)** (`nn.BCELoss()`) | Use if input features are binary or normalized between 0 and 1. Often used in Variational Autoencoders. |
# | **Huber Loss** (`torch.nn.SmoothL1Loss`)        | Combines benefits of MSE and MAE; less sensitive to outliers than MSE.                                  |
# | **Custom Loss**                                 | You can define custom losses, e.g., weighted reconstruction errors or perceptual losses for images.     |

# %% [markdown]
# https://docs.pytorch.org/docs/stable/optim.html

# %% [markdown]
# | Optimizer                     | Description / When to Use                                                             |
# | ----------------------------- | ------------------------------------------------------------------------------------- |
# | **SGD** (`optim.SGD`)         | Classic stochastic gradient descent; slower but sometimes better generalization.      |
# | **RMSProp** (`optim.RMSprop`) | Good for recurrent networks and non-stationary objectives; adapts learning rate.      |
# | **AdamW** (`optim.AdamW`)     | Variant of Adam with better weight decay handling; often improves regularization.     |
# | **Adagrad** (`optim.Adagrad`) | Adapts learning rate based on frequency of parameter updates; useful for sparse data. |

# %%
set_seed(42)
trained_model, train_losses, val_losses = train_autoencoder_checkpoint(
    model = model_ae, 
    X_train = X_scaled_train, 
    X_val = X_scaled_val, 
    epochs=100, 
    checkpoint_every=20, 
    early_stopping_patience=10,
    run_dir="model_checkpoint"
)
# Out:
# function: train_autoencoder_checkpoint is starting...
# Epoch [1/100] - Train Loss: 0.9926, Val Loss: 0.9671
# Epoch [2/100] - Train Loss: 0.9617, Val Loss: 0.9498
# Epoch [3/100] - Train Loss: 0.9524, Val Loss: 0.9473
# Epoch [4/100] - Train Loss: 0.9498, Val Loss: 0.9467
# Epoch [5/100] - Train Loss: 0.9480, Val Loss: 0.9456
# Epoch [6/100] - Train Loss: 0.9463, Val Loss: 0.9448
# Epoch [7/100] - Train Loss: 0.9449, Val Loss: 0.9451
# Epoch [8/100] - Train Loss: 0.9435, Val Loss: 0.9443
# Epoch [9/100] - Train Loss: 0.9424, Val Loss: 0.9438
# Epoch [10/100] - Train Loss: 0.9410, Val Loss: 0.9434
# Epoch [11/100] - Train Loss: 0.9402, Val Loss: 0.9429
# Epoch [12/100] - Train Loss: 0.9392, Val Loss: 0.9424
# Epoch [13/100] - Train Loss: 0.9381, Val Loss: 0.9422
# Epoch [14/100] - Train Loss: 0.9371, Val Loss: 0.9415
# Epoch [15/100] - Train Loss: 0.9361, Val Loss: 0.9418
# Epoch [16/100] - Train Loss: 0.9351, Val Loss: 0.9408
# Epoch [17/100] - Train Loss: 0.9341, Val Loss: 0.9407
# Epoch [18/100] - Train Loss: 0.9331, Val Loss: 0.9401
# Epoch [19/100] - Train Loss: 0.9326, Val Loss: 0.9400
# Epoch [95/100] - Train Loss: 0.9070, Val Loss: 0.9234
# Epoch [96/100] - Train Loss: 0.9064, Val Loss: 0.9239
# Epoch [97/100] - Train Loss: 0.9065, Val Loss: 0.9236
# Epoch [98/100] - Train Loss: 0.9059, Val Loss: 0.9230
# Epoch [99/100] - Train Loss: 0.9064, Val Loss: 0.9229
# Epoch [100/100] - Train Loss: 0.9058, Val Loss: 0.9222
# function: save_checkpoint is starting...
# ✅ Saved checkpoint: model_checkpoint\20250819_144912\checkpoint_epoch99.pkl
# function: save_checkpoint successfully executed at 0.0047304630279541016s
# function: train_autoencoder_checkpoint successfully executed at 49.78476929664612s

# %%
# resume case

# trained_model, train_losses, val_losses = train_autoencoder_checkpoint(
#         model = model_ae, 
#         X_train = X_scaled_train, 
#         X_val = X_scaled_val, 
#         epochs=120, 
#         checkpoint_every=20, 
#         checkpoint_path=r"model_checkpoint\20250814_164332\checkpoint_epoch99.pkl",
#         early_stopping_patience=10,
#         )

# %%
# trained_model, train_losses, val_losses, last_epoch = load_pickled_autoencoder(
#     r"model_checkpoint\20250814_164332\checkpoint_epoch99.pkl",
#     model=model_ae,
#     device=torch.device('cpu')
# )

# %%
trained_model
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=60, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=7, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=7, out_features=3, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=3, out_features=7, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=7, out_features=15, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=15, out_features=30, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=30, out_features=60, bias=True)
#   )
# )

# %%
# set_seed(42)
# trained_model , train_losses, val_losses= train_autoencoder(model=model_ae, 
#                                                             X_train=X_scaled_train,
#                                                             X_val = X_scaled_val, 
#                                                             epochs=50, 
#                                                             batch_size=64)

# %% [markdown]
# What the graph shows:
# - X-axis: Epochs (how many times the model has seen the training data)
# - Y-axis: Loss (how well the model reconstructs input — lower is better)
#
# There are two curves:
# - Training Loss: Error on the training data the model learned from
# - Validation Loss: Error on unseen data (validation set)
#
# Goal: Both losses should decrease and stay close to each other.
#
# If validation loss starts increasing while training loss decreases, it’s a sign to stop training or apply techniques to reduce overfitting.

# %%
plot_learning_curve(train_losses, val_losses)
# Out:
# function: plot_learning_curve is starting...
# function: plot_learning_curve successfully executed at 0.16640973091125488s

# %% [markdown]
# ### Grid search - skip รันนานเกิน เอาเวลาไปเพิ่ม epoch

# %% [markdown]
# | Parameter      | What it controls                  | Why tune it?                         |
# | -------------- | --------------------------------- | ------------------------------------ |
# | encoding\_dim  | Size of compressed representation | Balance between detail & compression |
# | hidden\_layers | Number & size of layers in model  | Model complexity & learning power    |
# | activation     | Function deciding neuron output   | How model learns patterns            |
# | batch\_size    | Number of samples per update      | Stability & speed of training        |
# | lr             | Step size for weight updates      | Training speed & convergence         |

# %%
param_grid = {
    "encoding_dim": [2, 3, 4],
    "hidden_layers": [[8], [8, 4], [16, 8]],
    "activation": [nn.ReLU, nn.Tanh],
    "batch_size": [32, 64],
    "lr": [1e-3, 5e-4]
}

## รันนานมาก ขอคอมมเม้นไว้ก่อน
# best_model, best_config, best_val_loss = tune_autoencoder_grid(
#     X_train=X_train,    # your normal train data (numpy or pd.DataFrame)
#     X_val=X_val,        # your normal validation data (numpy or pd.DataFrame)
#     param_grid=param_grid,
#     epochs=50,
#     verbose=True
# )

# print("Best config found:", best_config)

# %% [markdown]
# ### Predict and Test Performance

# %% [markdown]
# - หลังจากได้โมเดล เราลองใส่ X_test เข้าไปเพื่อให้ได้  y_predict
# - แล้วทดสอบผลกับ y_test

# %%
recon_error = get_reconstruction_error(trained_model, X_scaled_test)
recon_error
# Out:
# function: get_reconstruction_error is starting...
# function: get_reconstruction_error successfully executed at 0.0077991485595703125s
# array([ 1.29081144,  0.96418546,  0.8268388 , ..., 11.47946778,
#         0.97692199,  0.98493524], shape=(2000,))

# %%
# Pick a threshold (e.g., 95th percentile of normal errors)
threshold = np.percentile(recon_error[y_test == 0], 95)
threshold
# Out:
# np.float64(1.227143467933436)

# %%
# Flag anomalies
y_pred = flag_anomalies(recon_error, threshold)
y_pred
# Out:
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 0.0001456737518310547s
# array([1, 0, 0, ..., 1, 0, 0], shape=(2000,))

# %% [markdown]
# #### [hide] one threshold check

# %%
# เราใส่ Testดาต้าทั้งหมด (f / nf) เข้าไปเพื่อเทส (assume ว่าตัวโมเดลเรียนรู้ pattern ความปกติมาแล้ว)
# recon_error, predicted_fraud = detect_anomalies(trained_model, X_test, y_test,threshold_quantile=95)
_, _ = detect_anomalies(trained_model, X_scaled_test, y_test,threshold_quantile=95)
# Out:
# function: detect_anomalies is starting...
# Threshold (q=95): 1.2271
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      1905
#            1       0.50      1.00      0.66        95
#
#     accuracy                           0.95      2000
#    macro avg       0.75      0.97      0.82      2000
# weighted avg       0.98      0.95      0.96      2000
#
# function: detect_anomalies successfully executed at 0.023388147354125977s

# %% [markdown]
# ### Embeddings

# %%
embeddings = extract_embeddings(trained_model, X_scaled_test)
# Out:
# function: extract_embeddings is starting...
# function: extract_embeddings successfully executed at 0.0014116764068603516s

# %%
embeddings
# Out:
# array([[-2.1102934 ,  1.5189673 ,  3.2775836 ],
#        [-1.5239813 ,  0.4163871 ,  1.2509314 ],
#        [-2.3633692 , -0.31765935,  1.2171339 ],
#        ...,
#        [-1.4627483 , -0.6130999 ,  0.78815174],
#        [-1.5741929 , -0.18077956,  2.7995346 ],
#        [-1.6617069 , -0.5870987 ,  2.172816  ]],
#       shape=(2000, 3), dtype=float32)

# %%
# 1. Only true labels
# plot_latent_space(embeddings, y_test=y_test, encoding_dim=3)

# # 2. Only predicted labels
# plot_latent_space(embeddings, y_pred=predicted_fraud, encoding_dim=3)

# # 3. Compare both
plot_latent_space(embeddings, y_test=y_test, y_pred=y_pred, encoding_dim=3)
# Out:
# function: plot_latent_space is starting...
# function: plot_latent_space successfully executed at 0.5853705406188965s

# %%
pd.DataFrame({
    "y_test": pd.Series(y_test).value_counts(),
    "y_pred": pd.Series(y_pred).value_counts()
}).fillna(0).astype(int)
# Out:
#    y_test  y_pred
# 0    1905    1809
# 1      95     191

# %% [markdown]
# ### Packing

# %%
df_lables = create_pack_results(test_df, y_pred, experiment_name='ae_all_1')
df_lables = df_lables.set_index('sales_id')
df_lables
# Out:
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.0007369518280029297s
#           ae_all_1
# sales_id
# 8751             1
# 3108             0
# 7395             0
# 1373             0
# 1858             0
# ...            ...
# 3178             0
# 9980             0
# 1440             1
# 8684             0
# 3563             0
#
# [2000 rows x 1 columns]

# %%
# # First experiment
# results_df = create_results_df_wide(test_df, y_pred_ae1, experiment_name='ae_1')

# # Second experiment
# results_df = append_experiment_results(results_df, y_pred_ae2, experiment_name='ae_2')

# # Third experiment
# results_df = append_experiment_results(results_df, y_pred_ae3, experiment_name='ae_3')

# results_df

# %%
from package.model_deep_ae import (
                                evaluate_fraud_predictions,
                                evaluate_thresholds)

# %% [markdown]
# [13-08-2025] comment bro - ดู conversion metrix ของแต่ละ percentile -> done

# %%
res_1 = evaluate_thresholds(x_scaled = X_scaled_test , 
                    test_df=test_df ,
                    y_test=y_test , 
                    recon_error=recon_error ,
                    true_fraud_list=true_fraud_list)
# Out:
# function: evaluate_thresholds is starting...
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 8.893013000488281e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00039649009704589844s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 5.602836608886719e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00024318695068359375s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 4.291534423828125e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.000274658203125s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 4.291534423828125e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00020456314086914062s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 4.315376281738281e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00018095970153808594s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 6.961822509765625e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00028204917907714844s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 5.054473876953125e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00022554397583007812s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 4.839897155761719e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.0002765655517578125s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 7.104873657226562e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00020623207092285156s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 2.5987625122070312e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00016641616821289062s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 2.5033950805664062e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00010085105895996094s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 2.574920654296875e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.00010561943054199219s
# function: flag_anomalies is starting...
# function: flag_anomalies successfully executed at 2.8371810913085938e-05s
# function: create_pack_results is starting...
# function: create_pack_results successfully executed at 0.000164031982421875s
# function: evaluate_fraud_predictions is starting...
# Total input: 2000
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 102.17it/s]
# function: evaluate_fraud_predictions successfully executed at 0.1356675624847412s
# function: evaluate_thresholds successfully executed at 0.15719389915466309s

# %%
res_1
# Out:
#            experiments  total_alert  tp    fp    tn  fn  precision  recall  \
# 0   ae_default_all_p10         1809  95  1714   191   0   0.052515     1.0
# 1   ae_default_all_p20         1619  95  1524   381   0   0.058678     1.0
# 2   ae_default_all_p30         1428  95  1333   572   0   0.066527     1.0
# 3   ae_default_all_p40         1238  95  1143   762   0   0.076737     1.0
# 4   ae_default_all_p50         1047  95   952   953   0   0.090735     1.0
# 5   ae_default_all_p60          857  95   762  1143   0   0.110852     1.0
# 6   ae_default_all_p70          667  95   572  1333   0   0.142429     1.0
# 7   ae_default_all_p80          476  95   381  1524   0   0.199580     1.0
# 8   ae_default_all_p85          381  95   286  1619   0   0.249344     1.0
# 9   ae_default_all_p90          286  95   191  1714   0   0.332168     1.0
# 10  ae_default_all_p95          191  95    96  1809   0   0.497382     1.0
# 11  ae_default_all_p97          153  95    58  1847   0   0.620915     1.0
# 12  ae_default_all_p99          115  95    20  1885   0   0.826087     1.0
#
#         f0.5        f1
# 0   0.064793  0.099790
# 1   0.072287  0.110852
# 2   0.081798  0.124754
# 3   0.094115  0.142536
# 4   0.110904  0.166375
# 5   0.134828  0.199580
# 6   0.171915  0.249344
# 7   0.237619  0.332750
# 8   0.293391  0.399160
# 9   0.383374  0.498688
# 10  0.552969  0.664336
# 11  0.671853  0.766129
# 12  0.855856  0.904762

# %% [markdown]
# # [13-08-2025] ตัด label ว่า แล้วตัวที่ predict (แดง) อยู่่ใน่ กลุ่มก้อน
# หา overlap ว่าเกิดเท่าไหร่
# มิติเล็กลงเห็นไร

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.cluster import DBSCAN
# from sklearn.preprocessing import StandardScaler

# def cluster_embeddings(embeddings, sales_ids=None, labels=None, eps=0.5, min_samples=5):
#     """
#     Cluster 3D embeddings using DBSCAN and visualize results.
    
#     Parameters:
#     - embeddings: np.ndarray (n_samples, 3)
#     - sales_ids: list or array of IDs (optional)
#     - labels: list or array of fraud labels (optional)
#     - eps: DBSCAN eps parameter
#     - min_samples: DBSCAN min_samples parameter
    
#     Returns:
#     - DataFrame with sales_id, cluster_id, and label (if provided)
#     """
    
#     # Standardize embeddings for DBSCAN
#     embeddings_scaled = StandardScaler().fit_transform(embeddings)
    
#     # Run DBSCAN
#     dbscan = DBSCAN(eps=eps, min_samples=min_samples)
#     cluster_ids = dbscan.fit_predict(embeddings_scaled)
    
#     # Prepare results DataFrame
#     df = pd.DataFrame({
#         "sales_id": sales_ids if sales_ids is not None else np.arange(len(embeddings)),
#         "cluster_id": cluster_ids
#     })
    
#     if labels is not None:
#         df["label"] = labels
    
#     # Plot results
#     fig = plt.figure(figsize=(14, 6))
    
#     ax1 = fig.add_subplot(121, projection='3d')
#     scatter1 = ax1.scatter(embeddings[:, 0], embeddings[:, 1], embeddings[:, 2],
#                            c=cluster_ids, cmap='tab10', s=20)
#     ax1.set_title("Clusters (DBSCAN)")
#     plt.colorbar(scatter1, ax=ax1, label="Cluster ID")
    
#     ax2 = fig.add_subplot(122, projection='3d')
#     if labels is not None:
#         scatter2 = ax2.scatter(embeddings[:, 0], embeddings[:, 1], embeddings[:, 2],
#                                c=labels, cmap='coolwarm', s=20)
#         ax2.set_title("Fraud vs Normal")
#         plt.colorbar(scatter2, ax=ax2, label="Label (0=Normal, 1=Fraud)")
#     else:
#         ax2.set_title("No Labels Provided")
    
#     plt.show()
    
#     return df

# %%
# df_clusters = cluster_embeddings(
#     embeddings=embeddings,
#     sales_ids=np.arange(len(embeddings)),
#     labels=np.random.randint(0, 2, size=embeddings.shape[0]),  # Replace with your real labels
#     eps=0.5,
#     min_samples=5
# )
# df_clusters

# %% [markdown]
# # [13-08-2025] อยากให้ลองทำทั้ง novelty , anomaly and supervised (เอาคนที่เรา predict จาก novelty/anomaly ไปเป็น label)
